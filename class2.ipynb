# %% [markdown]
# <a href="https://colab.research.google.com/github/tanixtreme/pesuio-slot16/blob/main/class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("train.csv")
df.head()
# Out:
#          Date  store  product  number_sold
# 0  2010-01-01      0        0          801
# 1  2010-01-02      0        0          810
# 2  2010-01-03      0        0          818
# 3  2010-01-04      0        0          796
# 4  2010-01-05      0        0          808

# %%
df.head()
df.tail()
# Out:
#               Date  store  product  number_sold
# 230085  2018-12-27      6        9          890
# 230086  2018-12-28      6        9          892
# 230087  2018-12-29      6        9          895
# 230088  2018-12-30      6        9          899
# 230089  2018-12-31      6        9          912

# %% [markdown]
# head() and tail() -- the head() method returns the first five rows and tail(), the last five rows of a dataset

# %%
df.sample
# Out:
# <bound method NDFrame.sample of               Date  store  product  number_sold
# 0       2010-01-01      0        0          801
# 1       2010-01-02      0        0          810
# 2       2010-01-03      0        0          818
# 3       2010-01-04      0        0          796
# 4       2010-01-05      0        0          808
# ...            ...    ...      ...          ...
# 230085  2018-12-27      6        9          890
# 230086  2018-12-28      6        9          892
# 230087  2018-12-29      6        9          895
# 230088  2018-12-30      6        9          899
# 230089  2018-12-31      6        9          912
#
# [230090 rows x 4 columns]>

# %% [markdown]
# sample() -- it returns a random row of a dataset

# %%
df.shape
# Out:
# (230090, 4)

# %% [markdown]
# shape -- it returns a tuple with the number of rows and columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230090 entries, 0 to 230089
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Date         230090 non-null  object
#  1   store        230090 non-null  int64
#  2   product      230090 non-null  int64
#  3   number_sold  230090 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.0+ MB

# %% [markdown]
# info() -- Returns overall information about a dataset

# %%
df.describe()
# Out:
#                store        product    number_sold
# count  230090.000000  230090.000000  230090.000000
# mean        3.000000       4.500000     780.926107
# std         2.000004       2.872288     204.096737
# min         0.000000       0.000000     238.000000
# 25%         1.000000       2.000000     722.000000
# 50%         3.000000       4.500000     835.000000
# 75%         5.000000       7.000000     914.000000
# max         6.000000       9.000000    1205.000000

# %% [markdown]
# describe() Returns the major statistics of a dataset, including the number of non-null values, the minimum, maximum, and mean values, and percentages.

# %%
df.dtypes
# Out:
# Date           object
# store           int64
# product         int64
# number_sold     int64
# dtype: object

# %% [markdown]
# dtypes -- Returns the data types of a dataset by column.

# %%
df.columns
# Out:
# Index(['Date', 'store', 'product', 'number_sold'], dtype='object')

# %% [markdown]
# columns -- Returns the column names of a dataset

# %%
df.count()
# Out:
# Date           230090
# store          230090
# product        230090
# number_sold    230090
# dtype: int64

# %% [markdown]
# count() -- Returns the count of non-null values in a dataset

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# plot() -- creates plots such as line, bar, barh, hist, box, area, density, pie, and scatter according to the values of the dataset.

# %%
df.dropna()
# Out:
#               Date  store  product  number_sold
# 0       2010-01-01      0        0          801
# 1       2010-01-02      0        0          810
# 2       2010-01-03      0        0          818
# 3       2010-01-04      0        0          796
# 4       2010-01-05      0        0          808
# ...            ...    ...      ...          ...
# 230085  2018-12-27      6        9          890
# 230086  2018-12-28      6        9          892
# 230087  2018-12-29      6        9          895
# 230088  2018-12-30      6        9          899
# 230089  2018-12-31      6        9          912
#
# [230090 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("pesu-io.csv")

data['Period'] = pd.to_datetime(data['Period'], format='%d.%m.%Y')

data.fillna(0, inplace=True)

plt.figure(figsize=(12, 6))
plt.bar(data['Period'], data['Revenue'], label='Revenue', width=20, alpha=0.7, color='b')
plt.bar(data['Period'], data['Sales_quantity'], label='Sales Quantity', width=20, alpha=0.7, color='g')

ax = plt.gca()
ax2 = ax.twinx()
ax2.bar(data['Period'], data['Average_cost'], label='Average Cost', width=20, alpha=0.7, color='y')

plt.xlabel('Year-Month')
plt.ylabel('Revenue and Sales Quantity')
ax2.set_ylabel('Average Cost')
plt.title('Monthly Data from 2015 to 2020')
plt.xticks(rotation=45)

lines1, labels1 = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("pesu-io.csv")

data['Period'] = pd.to_datetime(data['Period'], format='%d.%m.%Y')

data.fillna(0, inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(data['Period'], data['Revenue'], label='Revenue', color='dodgerblue')

plt.plot(data['Period'], data['Average_cost'], label='Average Cost', color='gold')
plt.plot(data['Period'], data['The_average_annual_payroll_of_the_region'], label='Annual Payroll', color='darkorange')

plt.xlabel('Year-Month')
plt.ylabel('Values')
plt.title('Monthly Data from 2015 to 2020')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("pesu-io.csv")

data['Period'] = pd.to_datetime(data['Period'], format='%d.%m.%Y')

data.fillna(0, inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(data['Period'], data['Sales_quantity'], label='Sales Quantity', color='limegreen')

plt.xlabel('Year-Month')
plt.ylabel('Values')
plt.title('Monthly Data from 2015 to 2020')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
